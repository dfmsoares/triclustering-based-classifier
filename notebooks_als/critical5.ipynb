# %%
from interpretability import run_interpretability
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
import shap
from get_patterns import Patterns
# Out:
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
# The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.

# %% [markdown]
# # Critical 5 - Need for a wheelchair

# %% [markdown]
# ### *90 days*

# %%
t_file = '/content/drive/My Drive/Colab Notebooks/critical_5/5_90_out_1_DistanceMatrix.csv'
model = SVC(probability=True)
shap_values, X, X_original = run_interpretability(3, t_file, model)
# Out:
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   0%|          | 0/780 [00:00<?, ?it/s]
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.444e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 134 iterations, alpha=3.049e-03, previous alpha=3.049e-03, with an active set of 37 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.444e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# ...

# %%
shap.summary_plot(shap_values, X_original, plot_type='bar')

# %%
p = Patterns()
p.load_triclusters("/content/drive/My Drive/Colab Notebooks/critical_5/5_90_out_1.txt")

# %%
ids= [(0,1), (65,2), (15,2), (27,2), (81,2), (55,2), (103,2), (18,2), (21,2), (3,2), (35,2),
(20,2), (2,2), (39,1), (45,1), (1,1), (43,1), (20,1), (38,1), (3,1)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_0_1: [ALS-FRS=37.0, ALS-FRS-R=45.0]
# Tric_65_2: [ALS-FRSr=4.0, R=12.0]
# Tric_15_2: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0]
# Tric_27_2: [ALS-FRSb=12.0, R=12.0]
# Tric_81_2: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_55_2: [R=12.0]
# Tric_103_2: [R=12.0, mitos_s=1.0]
# Tric_18_2: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_21_2: [ALS-FRSb=12.0, R=12.0, mitos_s=1.0]
# Tric_3_2: [ALS-FRSb=12.0]
# Tric_35_2: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_20_2: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_2_2: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_39_1: [ALS-FRSsUL=12.0]
# Tric_45_1: [ALS-FRSsUL=12.0, mitos_s=1.0]
# Tric_1_1: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_43_1: [ALS-FRSsUL=12.0, R=12.0]
# Tric_20_1: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_38_1: [ALS-FRSsUL=12.0, ALS-FRSr=4.0]
# Tric_3_1: [ALS-FRSb=12.0]

# %% [markdown]
# ### 180 d

# %%
t_file = '/content/drive/My Drive/Colab Notebooks/critical_5/5_180_out_1_DistanceMatrix.csv'
model = SVC(probability=True)
shap_values, X, X_test = run_interpretability(5, t_file, model)
# Out:
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   0%|          | 0/1812 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.524e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.524e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# ...

# %%
shap.summary_plot(shap_values, X_test, plot_type='bar')

# %%
p = Patterns()
p.load_triclusters("/content/drive/My Drive/Colab Notebooks/critical_5/5_180_out_1.txt")

# %%
ids= [(1,2), (47,0), (1,1), (1,0), (866,2), (719,4), (7,0), (916,0), (1746,1), (13,0), (3,0),
(0,1), (145,0), (31,1), (4183,0), (8,0), (2290,1), (875,1), (2247,0), (8,1)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_1_2: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_47_0: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_1_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_1_0: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_866_2: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_719_4: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0]
# Tric_7_0: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_916_0: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_1746_1: [R=12.0, mitos_s=1.0]
# Tric_13_0: [mitos_s=1.0]
# Tric_3_0: [ALS-FRSr=4.0]
# Tric_0_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_145_0: [ALS-FRSr=4.0]
# Tric_31_1: [mitos_s=1.0]
# Tric_4183_0: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_8_0: [R=12.0, mitos_s=1.0]
# Tric_2290_1: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_875_1: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_2247_0: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_8_1: [R=12.0, mitos_s=1.0]

# %% [markdown]
# ### 365 d

# %%
t_file = '/content/drive/My Drive/Colab Notebooks/critical_5/5_365_out_1_DistanceMatrix.csv'
model = SVC(probability=True)
shap_values, X, X_original = run_interpretability(5, t_file, model)
# Out:
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   0%|          | 0/1244 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=3.720e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=3.719e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# ...

# %%
shap.summary_plot(shap_values, X_original, plot_type='bar')

# %%
p = Patterns()
p.load_triclusters("/content/drive/My Drive/Colab Notebooks/critical_5/5_365_out_1.txt")

# %%
ids= [(1,2), (1,1), (5,1), (0,1), (1,0), (2,1), (2,2), (11,0), (4,0), (2,0), (12,0),
(6,0), (25,0), (9,1), (4,1), (10,1), (2,3), (3,0), (30,0), (32,2)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_1_2: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_1_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_5_1: [mitos_s=1.0]
# Tric_0_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_1_0: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_2_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_2_2: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_11_0: [R=12.0, mitos_s=1.0]
# Tric_4_0: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_2_0: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_12_0: [R=12.0]
# Tric_6_0: [mitos_s=1.0]
# Tric_25_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_9_1: [ALS-FRSb=12.0, R=12.0, mitos_s=1.0]
# Tric_4_1: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_10_1: [mitos_s=1.0]
# Tric_2_3: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_3_0: [ALS-FRSr=4.0]
# Tric_30_0: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_32_2: [ALS-FRSb=12.0, ALS-FRSr=4.0]
