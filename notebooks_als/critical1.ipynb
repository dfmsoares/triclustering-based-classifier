# %%
from interpretability import run_interpretability
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
import shap
from get_patterns import Patterns
# Out:
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
# The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.

# %% [markdown]
# # Critical 1 - Need for NIV

# %% [markdown]
# ### *90 days*

# %%
t_file = '/content/drive/My Drive/Colab Notebooks/critical_NIV/90_out_1_DistanceMatrix.csv'
model = SVC(probability=True)
shap_values, X, X_test = run_interpretability(5, t_file, model)
# Out:
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   0%|          | 0/2120 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.600e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.600e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# ...

# %%
shap.summary_plot(shap_values, X_test)

# %%
p = Patterns()
p.load_triclusters("/content/drive/My Drive/Colab Notebooks/critical_NIV/1_90_out_1.txt")

# %%
ids= [(2,1), (1,1), (2,2), (5,0), (1,0), (10,0), (9,1), (0,1), (10,2), (2,0), (5,1),
(18,0), (17,1), (18,1), (21,0), (30,2), (21,1), (9,0), (30,0), (20,1)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_2_1: [ALS-FRSb=12.0]
# Tric_1_1: [ALS-FRSb=12.0]
# Tric_2_2: [ALS-FRSb=12.0]
# Tric_5_0: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_1_0: [ALS-FRSb=12.0]
# Tric_10_0: [ALS-FRSr=4.0]
# Tric_9_1: [ALS-FRSr=4.0]
# Tric_0_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_10_2: [ALS-FRSr=4.0]
# Tric_2_0: [ALS-FRSb=12.0]
# Tric_5_1: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_18_0: [ALS-FRSb=12.0, R=12.0]
# Tric_17_1: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0]
# Tric_18_1: [ALS-FRSb=12.0, R=12.0]
# Tric_21_0: [ALS-FRSr=4.0, R=12.0]
# Tric_30_2: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_21_1: [ALS-FRSr=4.0, R=12.0]
# Tric_9_0: [ALS-FRSr=4.0]
# Tric_30_0: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_20_1: [ALS-FRSr=4.0, R=12.0]

# %% [markdown]
# ### *180 days*

# %%
t_file = '/content/drive/My Drive/Colab Notebooks/critical_NIV/180_out_1_DistanceMatrix.csv'
model = SVC(probability=True)
shap_values, X, X_test = run_interpretability(4, t_file, model)
# Out:
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   0%|          | 0/1732 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.492e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.491e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# ...

# %%
shap.summary_plot(shap_values, X_test)

# %%
p = Patterns()
p.load_triclusters("/content/drive/My Drive/Colab Notebooks/critical_NIV/1_180_out_1.txt")

# %%
ids= [(4625,1), (4621,0), (4621,1), (4625,0), (0,1), (104,3), (120,3), (2,0), (37,0), (2,2), (4227,1), (39,2),
(1,0), (34,1), (39,3), (67,3), (41,1), (38,2), (67,0), (1861,3)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_4625_1: [FVC=85.14384384384384]
# Tric_4621_0: [ALS-FRSb=12.0, FVC=92.13015564202334]
# Tric_4621_1: [ALS-FRSb=12.0, FVC=89.64447852760736]
# Tric_4625_0: [FVC=90.71904024767802]
# Tric_0_1: [ALS-FRS=37.0, ALS-FRS-R=45.0]
# Tric_104_3: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_120_3: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0]
# Tric_2_0: [R=12.0]
# Tric_37_0: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_2_2: [R=12.0]
# Tric_4227_1: [ALS-FRS=37.0, ALS-FRS-R=45.0]
# Tric_39_2: [ALS-FRSr=4.0]
# Tric_1_0: [R=12.0]
# Tric_34_1: [ALS-FRSb=12.0]
# Tric_39_3: [ALS-FRSr=4.0]
# Tric_67_3: [ALS-FRSr=4.0, R=12.0]
# Tric_41_1: [ALS-FRSr=4.0]
# Tric_38_2: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_67_0: [ALS-FRSr=4.0, R=12.0]
# Tric_1861_3: [ALS-FRSb=12.0, R=12.0, mitos_s=1.0]

# %% [markdown]
# ### *365 days*

# %%
t_file = '/content/drive/My Drive/Colab Notebooks/critical_NIV/365_out_1_DistanceMatrix.csv'
model = SVC(probability=True)
shap_values, X, X_test = run_interpretability(5, t_file, model)
# Out:
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   0%|          | 0/1248 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=4.239e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=4.239e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# ...

# %%
shap.summary_plot(shap_values, X_test)

# %%
p = Patterns()
p.load_triclusters("/content/drive/My Drive/Colab Notebooks/critical_NIV/1_365_out_1.txt")

# %%
ids= [(1,2), (1,1), (0,1), (2,0), (4,2), (11,1), (6,3), (4,1), (5,1), (32,1), (6,1), (17,2),
(10,1), (5,2), (1,0), (11,0), (33,2), (802,3), (5,3), (2,1)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_1_2: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_1_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_0_1: [ALS-FRS=38.0, ALS-FRS-R=45.0]
# Tric_2_0: [ALS-FRSr=4.0, R=12.0]
# Tric_4_2: [ALS-FRSr=4.0, R=12.0]
# Tric_11_1: [ALS-FRS-R=46.0]
# Tric_6_3: [ALS-FRSr=4.0, R=12.0]
# Tric_4_1: [ALS-FRSr=4.0, R=12.0]
# Tric_5_1: [ALS-FRSr=4.0, R=12.0]
# Tric_32_1: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_6_1: [ALS-FRSr=4.0, R=12.0]
# Tric_17_2: [ALS-FRSb=12.0]
# Tric_10_1: [ALS-FRS=38.0]
# Tric_5_2: [ALS-FRSr=4.0, R=12.0]
# Tric_1_0: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_11_0: [ALS-FRS-R=46.0]
# Tric_33_2: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_802_3: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_5_3: [ALS-FRSr=4.0, R=12.0]
# Tric_2_1: [ALS-FRSr=4.0, R=12.0]
