# %%
import sys, os

p = os.path.abspath('..')
sys.path.insert(1, p)

from interpretability import run_interpretability, shap_force
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
import shap
from get_patterns import Patterns

# %% [markdown]
# # Critical 3 - PEG indication

# %% [markdown]
# ### *90 days*

# %%
t_file = '../../critical_3/triclustering_90/matrices/trics/3TPS/out_1_DistanceMatrix.csv'
model = RandomForestClassifier(n_estimators=100, max_depth=7500, random_state=0)
shap_values, X, X_original = run_interpretability(3, t_file, model)

# %%
shap.summary_plot(shap_values, X_original, plot_type='bar')

# %%
p = Patterns()
p.load_triclusters("../../critical_3/triclustering_90/triclusters/3TPS/out_1.txt")

# %%
ids= [(70,2), (13,2), (119,2), (3,2), (2,1), (40,2), (49,2), (72,2), (70,1), (104,2), (3,0),
(3,1), (66,1), (48,2), (1,0), (87,0), (72,1), (58,2), (117,2), (70,0)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_70_2: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_13_2: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_119_2: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_3_2: [ALS-FRSb=12.0]
# Tric_2_1: [ALS-FRSb=12.0]
# Tric_40_2: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_49_2: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_72_2: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_70_1: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_104_2: [ALS-FRSr=4.0, R=12.0]
# Tric_3_0: [ALS-FRSb=12.0]
# Tric_3_1: [ALS-FRSb=12.0]
# Tric_66_1: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_48_2: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_1_0: [ALS-FRS=35.0, FVC=92.16628099173553]
# Tric_87_0: [FVC=90.42852631578947]
# Tric_72_1: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_58_2: [R=12.0]
# Tric_117_2: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_70_0: [ALS-FRSb=12.0, mitos_s=1.0]

# %% [markdown]
# ### *180 days*

# %%
t_file = '../../critical_3/triclustering_180/matrices/trics/5TPS/out_1_DistanceMatrix.csv'
model = RandomForestClassifier(n_estimators=100, max_depth=7500, random_state=0)
shap_values, X, X_original = run_interpretability(5, t_file, model)

# %%
shap.summary_plot(shap_values, X_original, plot_type='bar')

# %%
p = Patterns()
p.load_triclusters("../../critical_3/triclustering_180/triclusters/5TPS/out_1.txt")

# %%
ids= [(152,4), (454,4), (649,4), (27,4), (1284,4), (1282,4), (686,4), (673,2), (691,4), (449,4), (448,4),
(685,2), (27,0), (706,4), (1,0), (686,3), (27,2), (152,3), (4,0), (490,4)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_152_4: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_454_4: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_649_4: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_27_4: [ALS-FRSb=12.0]
# Tric_1284_4: [mitos_s=1.0]
# Tric_1282_4: [mitos_s=1.0]
# Tric_686_4: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_673_2: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_691_4: [mitos_s=1.0]
# Tric_449_4: [ALS-FRSb=12.0, R=12.0, mitos_s=1.0]
# Tric_448_4: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_685_2: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_27_0: [ALS-FRSb=12.0]
# Tric_706_4: [mitos_s=1.0]
# Tric_1_0: [ALS-FRSb=12.0]
# Tric_686_3: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_27_2: [ALS-FRSb=12.0]
# Tric_152_3: [ALS-FRSb=12.0, ALS-FRSr=4.0]
# Tric_4_0: [ALS-FRSb=12.0]
# Tric_490_4: [ALS-FRSr=4.0, mitos_s=1.0]

# %% [markdown]
# ### *365 days*

# %%
t_file = '../../critical_3/triclustering_365/matrices/trics/5TPS/out_1_DistanceMatrix.csv'
model = RandomForestClassifier(n_estimators=100, max_depth=7500, random_state=0)
shap_values, X, X_original = run_interpretability(5, t_file, model)

# %%
shap.summary_plot(shap_values, X_original, plot_type='bar')

# %%
p = Patterns()
p.load_triclusters("../../critical_3/triclustering_365/triclusters/5TPS/out_1.txt")

# %%
ids= [(281,0), (882,0), (0,1), (96,0), (5,4), (298,0), (1170,0), (294,0), (13,0), (300,4), (300,0),
(39,0), (1284,1), (222,1), (203,1), (226,1), (977,1), (192,1), (1017,1), (96,1)]
for i, pos in ids:
    print(p.print_pattern_slice(i, pos))
# Out:
# Tric_281_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_882_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_0_1: [ALS-FRS=38.0, ALS-FRS-R=46.0]
# Tric_96_0: [ALS-FRSb=12.0]
# Tric_5_4: [ALS-FRSb=12.0]
# Tric_298_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_1170_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_294_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_13_0: [ALS-FRSb=12.0]
# Tric_300_4: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_300_0: [ALS-FRSb=12.0, mitos_s=1.0]
# Tric_39_0: [ALS-FRSb=12.0]
# Tric_1284_1: [mitos_s=1.0]
# Tric_222_1: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_203_1: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_226_1: [ALS-FRSb=12.0, ALS-FRSr=4.0, mitos_s=1.0]
# Tric_977_1: [ALS-FRSr=4.0, R=12.0, mitos_s=1.0]
# Tric_192_1: [ALS-FRSb=12.0, ALS-FRSr=4.0, R=12.0]
# Tric_1017_1: [ALS-FRSr=4.0, mitos_s=1.0]
# Tric_96_1: [ALS-FRSb=12.0]
